# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
model = tf.keras.models.load_model('terrain_recognition_model.h5')

# %%
img_path = "C:/Users/Karan/Desktop/Terrain Rec/Dataset DL/val/Grassy/Grassy (16)_9_10.png"

# %%
def plot_image(img_path):
    img = mpimg.imread(img_path)
    plt.imshow(img)
    plt.axis('off')  # Turn off axis
    plt.show()

# %%
#produces image array
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    return img_array

# %%
def predict_terrain(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)
    terrain_categories = ['Grassy', 'Marshy', 'Rocky', 'Sandy']
    predicted_category = terrain_categories[np.argmax(prediction)]
    plot_image(img_path)
    return predicted_category

# %%
preprocess_image(img_path)
# Out:
# array([[[[0.24705882, 0.32941177, 0.20784314],
#          [0.21176471, 0.28627452, 0.1764706 ],
#          [0.19607843, 0.27450982, 0.16862746],
#          ...,
#          [0.27450982, 0.34901962, 0.23921569],
#          [0.29803923, 0.36078432, 0.25490198],
#          [0.29411766, 0.35686275, 0.25490198]],
#
#         [[0.21960784, 0.3019608 , 0.18039216],
#          [0.1764706 , 0.25882354, 0.13725491],
#          [0.18431373, 0.27450982, 0.16078432],
#          ...,
#          [0.32941177, 0.3882353 , 0.29803923],
#          [0.23921569, 0.3019608 , 0.2       ],
#          [0.20784314, 0.2627451 , 0.17254902]],
#
#         [[0.2       , 0.29411766, 0.16078432],
#          [0.10196079, 0.20392157, 0.06666667],
#          [0.08627451, 0.18431373, 0.05882353],
#          ...,
#          [0.27058825, 0.32941177, 0.23921569],
#          [0.2       , 0.25490198, 0.16470589],
#          [0.17254902, 0.21960784, 0.13333334]],
#
#         ...,
#
# ...

# %%
predicted_category = predict_terrain(img_path)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
print('Predicted terrain category:', predicted_category)
# Out:
# Predicted terrain category: Grassy
